# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
drive = pd.read_csv("drive.csv")

# %%
drive
# Out:
#      speed  risk
# 0      200  95.0
# 1       90  20.0
# 2      300  98.0
# 3      110  60.0
# 4      240  72.0
# ..     ...   ...
# 117    310  96.0
# 118     85  19.0
# 119     25   2.0
# 120    210  73.0
# 121    125   NaN
#
# [122 rows x 2 columns]

# %%
plt.scatter(drive["speed"], drive["risk"], color = "red" )
plt.xlabel("Speed")
plt.ylabel("Risk")
plt.title("Risk Analysis")
# Out:
# Text(0.5, 1.0, 'Risk Analysis')

# %%
speed = drive[["speed"]]
risk = drive[["risk"]]

# %%
#train test split
from sklearn.model_selection import train_test_split

# %%
speedtrain, speedtest, risktrain, risktest = train_test_split(speed, risk, test_size=.40, random_state=1)

# %%
speedtrain
# Out:
#      speed
# 74      50
# 91     135
# 94     215
# 40     350
# 59      20
# ..     ...
# 9      260
# 72     370
# 12     310
# 107    240
# 37     280
#
# [73 rows x 1 columns]

# %%
speedtest
# Out:
#      speed
# 48      75
# 112    265
# 73     115
# 105    225
# 45     245
# 31     155
# 67     270
# 46     125
# 97     285
# 83     185
# 113    155
# 33      90
# 99     290
# 115    290
# 104     45
# 119     25
# 2      300
# 89      30
# 108     65
# 51      80
# 65     165
# 78      70
# 80     165
# 17     275
# 85     300
# 54     265
# 35     195
# 69     300
# 88      90
# 98     220
# 77     255
# 42     360
# 100    340
# 55     310
# 53     175
# 44      60
# 62     255
# 58     100
# 10     290
# 110    150
# 32     265
# 82     250
# 38     225
# 19     255
# 121    125
# 27     330
# 36      70
# 56     180
# 39     290

# %%
risktrain
# Out:
#      risk
# 74    6.0
# 91   29.0
# 94   62.0
# 40   98.0
# 59    1.0
# ..    ...
# 9    91.0
# 72   99.0
# 12   93.0
# 107  87.0
# 37   87.0
#
# [73 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
regra = LinearRegression()

# %%
regra.fit(speedtrain, risktrain)
# Out:
# LinearRegression()

# %%
regra.predict(speedtest)
# Out:
# array([[ 18.15494441],
#        [ 80.63519965],
#        [ 31.30868235],
#        [ 67.4814617 ],
#        [ 74.05833068],
#        [ 44.4624203 ],
#        [ 82.27941689],
#        [ 34.59711684],
#        [ 87.21206862],
#        [ 54.32772376],
#        [ 44.4624203 ],
#        [ 23.08759614],
#        [ 88.85628587],
#        [ 88.85628587],
#        [  8.28964095],
#        [  1.71277197],
#        [ 92.14472035],
#        [  3.35698922],
#        [ 14.86650992],
#        [ 19.79916165],
#        [ 47.75085479],
#        [ 16.51072716],
#        [ 47.75085479],
#        [ 83.92363414],
#        [ 92.14472035],
#        [ 80.63519965],
#        [ 57.61615825],
#        [ 92.14472035],
#        [ 23.08759614],
#        [ 65.83724446],
#        [ 77.34676516],
#        [111.87532727],
#        [105.2984583 ],
#        [ 95.43315484],
#        [ 51.03928927],
#        [ 13.22229268],
#        [ 77.34676516],
#        [ 26.37603062],
#        [ 88.85628587],
#        [ 42.81820306],
# ...

# %%
speedtest
# Out:
#      speed
# 48      75
# 112    265
# 73     115
# 105    225
# 45     245
# 31     155
# 67     270
# 46     125
# 97     285
# 83     185
# 113    155
# 33      90
# 99     290
# 115    290
# 104     45
# 119     25
# 2      300
# 89      30
# 108     65
# 51      80
# 65     165
# 78      70
# 80     165
# 17     275
# 85     300
# 54     265
# 35     195
# 69     300
# 88      90
# 98     220
# 77     255
# 42     360
# 100    340
# 55     310
# 53     175
# 44      60
# 62     255
# 58     100
# 10     290
# 110    150
# 32     265
# 82     250
# 38     225
# 19     255
# 121    125
# 27     330
# 36      70
# 56     180
# 39     290

# %%
risktest
# Out:
#      risk
# 48   45.0
# 112  85.0
# 73   29.0
# 105  74.0
# 45   79.0
# 31   36.0
# 67   88.0
# 46   37.0
# 97   91.0
# 83   38.0
# 113  35.0
# 33   50.0
# 99   94.0
# 115  96.0
# 104   5.0
# 119   2.0
# 2    98.0
# 89    3.0
# 108  47.0
# 51   11.0
# 65   17.0
# 78   49.0
# 80   13.0
# 17   89.0
# 85   97.0
# 54   90.0
# 35   12.0
# 69   97.0
# 88   20.0
# 98   41.0
# 77   89.0
# 42   99.0
# 100  99.0
# 55   97.0
# 53   39.0
# 44    5.0
# 62   88.0
# 58   21.0
# 10   82.0
# 110  10.0
# 32   92.0
# 82   82.0
# 38   43.0
# 19   97.0
# 121   NaN
# 27   97.0
# 36    9.0
# 56   61.0
# 39   94.0

# %%
plt.plot(drive.speed, regra.predict(drive[["speed"]]))
plt.scatter(drive["speed"], drive["risk"], color = "red")
plt.xlabel("Speed")
plt.ylabel("Risk")
plt.title("Risk Analysis")
# Out:
# Text(0.5, 1.0, 'Risk Analysis')

# %%
regra.predict([[123]])
# Out:
# /home/reza/miniconda3/envs/practice/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[33.93942994]])
